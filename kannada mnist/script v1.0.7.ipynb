# %% [markdown]
# Compatibility(for jupyter notebook environments only)

# %%
# !pip install keras==2.2.4
# Out:
# Collecting keras==2.2.4
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#      |████████████████████████████████| 317kB 2.6MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.12.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.0.8)
# Installing collected packages: keras
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# Successfully installed keras-2.2.4

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# # Load the Drive helper and mount
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # Imports

# %%
import keras
print(keras.__version__)
import tensorflow
print(tensorflow.__version__)
# Out:
# Using TensorFlow backend.
# 2.2.4
# 1.15.2

# %%
import os

import numpy as np
import pandas as pd
import tensorflow as tf

import keras.backend as K
from keras import callbacks
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.utils.data_utils import get_file
from keras import initializers, layers, models

import matplotlib.pyplot as plt


import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Layers in CapsNet

# %% [markdown]
# Define the key layers required to build any capsnet architecture

# %%
class Length(layers.Layer):
    """
    Compute the length of vectors. This is used to compute a Tensor that has the same shape with y_true in margin_loss
    inputs: shape=[dim_1, ..., dim_{n-1}, dim_n]
    output: shape=[dim_1, ..., dim_{n-1}]
    """
    def call(self, inputs, **kwargs):
        return K.sqrt(K.sum(K.square(inputs), -1))

    def compute_output_shape(self, input_shape):
        return input_shape[:-1]

class Mask(layers.Layer):
    """
    Mask a Tensor with shape=[None, d1, d2] by the max value in axis=1.
    Output shape: [None, d2]
    """
    def call(self, inputs, **kwargs):
        # use true label to select target capsule, shape=[batch_size, num_capsule]
        if type(inputs) is list:  # true label is provided with shape = [batch_size, n_classes], i.e. one-hot code.
            assert len(inputs) == 2
            inputs, mask = inputs
        else:  # if no true label, mask by the max length of vectors of capsules
            x = inputs
            # Enlarge the range of values in x to make max(new_x)=1 and others < 0
            x = (x - K.max(x, 1, True)) / K.epsilon() + 1
            mask = K.clip(x, 0, 1)  # the max value in x clipped to 1 and other to 0

        # masked inputs, shape = [batch_size, dim_vector]
        inputs_masked = K.batch_dot(inputs, mask, [1, 1])
        return inputs_masked

    def compute_output_shape(self, input_shape):
        if type(input_shape[0]) is tuple:  # true label provided
            return tuple([None, input_shape[0][-1]])
        else:
            return tuple([None, input_shape[-1]])


def squash(vectors, axis=-1):
    """
    The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
    :param vectors: some vectors to be squashed, N-dim tensor
    :param axis: the axis to squash
    :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (0.5 + s_squared_norm) / K.sqrt(s_squared_norm)
    return scale * vectors


class CapsuleLayer(layers.Layer):
    """
    The capsule layer. It is similar to Dense layer. Dense layer has `in_num` inputs, each is a scalar, the output of the 
    neuron from the former layer, and it has `out_num` output neurons. CapsuleLayer just expand the output of the neuron
    from scalar to vector. So its input shape = [None, input_num_capsule, input_dim_vector] and output shape = \
    [None, num_capsule, dim_vector]. For Dense Layer, input_dim_vector = dim_vector = 1.
    
    :param num_capsule: number of capsules in this layer
    :param dim_vector: dimension of the output vectors of the capsules in this layer
    :param num_routings: number of iterations for the routing algorithm
    """
    def __init__(self, num_capsule, dim_vector, num_routing=3,
                 kernel_initializer='glorot_uniform',
                 bias_initializer='zeros',
                 **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_vector = dim_vector
        self.num_routing = num_routing
        self.kernel_initializer = initializers.get(kernel_initializer)
        self.bias_initializer = initializers.get(bias_initializer)

    def build(self, input_shape):
        assert len(input_shape) >= 3, "The input Tensor should have shape=[None, input_num_capsule, input_dim_vector]"
        self.input_num_capsule = input_shape[1]
        self.input_dim_vector = input_shape[2]

        # Transformation matrix/Weight matrix
        self.W = self.add_weight(shape=[self.input_num_capsule, self.num_capsule, self.input_dim_vector, self.dim_vector],
                                 initializer=self.kernel_initializer,
                                 name='W')

        # Coupling coefficient. The redundant dimensions are just to facilitate subsequent matrix calculation.
        self.bias = self.add_weight(shape=[1, self.input_num_capsule, self.num_capsule, 1, 1],
                                    initializer=self.bias_initializer,
                                    name='bias',
                                    trainable=False)
        self.built = True

    def call(self, inputs, training=None):
        # inputs.shape=[None, input_num_capsule, input_dim_vector]
        # Expand dims to [None, input_num_capsule, 1, 1, input_dim_vector]
        inputs_expand = K.expand_dims(K.expand_dims(inputs, 2), 2)

        # Replicate(tile) num_capsule dimension to prepare being multiplied by W
        # Now it has shape = [None, input_num_capsule, num_capsule, 1, input_dim_vector]
        inputs_tiled = K.tile(inputs_expand, [1, 1, self.num_capsule, 1, 1])

        """  
        # Compute `inputs * W` by expanding the first dim of W. More time-consuming and need batch_size.
        # Now W has shape  = [batch_size, input_num_capsule, num_capsule, input_dim_vector, dim_vector]
        w_tiled = K.tile(K.expand_dims(self.W, 0), [self.batch_size, 1, 1, 1, 1])
        
        # Transformed vectors, inputs_hat.shape = [None, input_num_capsule, num_capsule, 1, dim_vector]
        inputs_hat = K.batch_dot(inputs_tiled, w_tiled, [4, 3])
        """
        
        # inputs_hat.shape = [None, input_num_capsule, num_capsule, 1, dim_vector]
        inputs_hat = tf.scan(lambda ac, x: K.batch_dot(x, self.W, [3, 2]),
                             elems=inputs_tiled,
                             initializer=K.zeros([self.input_num_capsule, self.num_capsule, 1, self.dim_vector]))

        # DYNAMIC ROUTING
        assert self.num_routing > 0, 'The num_routing should be > 0.'
        for i in range(self.num_routing):
            c = tf.nn.softmax(self.bias, dim=2)  # dim=2 is the num_capsule dimension
            outputs = squash(K.sum(c * inputs_hat, 1, keepdims=True))

            # last iteration needs not compute bias which will not be passed to the graph any more anyway.
            if i != self.num_routing - 1:
                # update the raw weights for the next routing iteration
                # by adding the agreement to the previous raw weights
                self.bias += K.sum(inputs_hat * outputs, -1, keepdims=True)

        return K.reshape(outputs, [-1, self.num_capsule, self.dim_vector])

    def compute_output_shape(self, input_shape):
        return tuple([None, self.num_capsule, self.dim_vector])


def PrimaryCap(inputs, dim_vector, n_channels, kernel_size, strides, padding):
    """
    Apply Conv2D `n_channels` times and concatenate all capsules
    :param inputs: 4D tensor, shape=[None, width, height, channels]
    :param dim_vector: the dim of the output vector of capsule
    :param n_channels: the number of types of capsules
    :return: output tensor, shape=[None, num_capsule, dim_vector]
    """
    output = layers.Conv2D(filters=dim_vector*n_channels, kernel_size=kernel_size, strides=strides, padding=padding)(inputs)
    outputs = layers.Reshape(target_shape=[-1, dim_vector])(output)
    return layers.Lambda(squash)(outputs)

# %% [markdown]
# # Build the network

# %% [markdown]
# Build the required capsnet architecture using the layers defined above

# %%
def CapsNet(input_shape, n_class, num_routing, digit_caps_dim_vector=16):
    """
    A Capsule Network on MNIST.
    :param input_shape: data shape, 4d, [None, width, height, channels]
    :param n_class: number of classes
    :param num_routing: number of routing iterations
    :return: A Keras Model with 2 inputs and 2 outputs
    """
    x = layers.Input(shape=input_shape)

    # Layer 1: Conventional Conv2D layer
    conv1 = layers.Conv2D(filters=256, kernel_size=9, strides=1, padding='valid', activation='relu', name='conv1')(x)
    conv1 = layers.BatchNormalization(name='batch_norm1')(conv1)

    # Layer 2: Conv2D layer with `squash` activation, then reshape to [None, num_capsule, dim_vector]
    primarycaps = PrimaryCap(conv1, dim_vector=8, n_channels=32, kernel_size=9, strides=2, padding='valid')

    # Layer 3: Capsule layer. Dynamic Routing algorithm works here.
    digitcaps = CapsuleLayer(num_capsule=n_class, dim_vector=digit_caps_dim_vector, num_routing=num_routing, name='digit_caps')(primarycaps)

    # Layer 4: This is an auxiliary layer to replace each capsule with its length. Just to match the true label's shape.
    out_caps = Length(name='out_caps')(digitcaps)

    y = layers.Input(shape=(n_class,))
    masked = Mask()([digitcaps, y])  # The true label is used to mask the output of capsule layer.

    """
    Novelty:
    As opposed to using the conventional dense network as a reconstruction/decoder network,
    this model architecture leverages "Deconvolution"(which actually is the Transposed Convolution)
    layer for reconstructing the input image from the learned features.
    Using such a decoder architecture makes intuitive sense over a dense network as similar decoder
    architectures have been deployed in other computer vision tasks such as Image/Instance segmentation.
    NOTE: the deconvolution name is a misnomer and the layer should more appropriately be called the
    transposed convolution layer, something which has been fixed in the later versions of keras and 
    tensorflow.
    """

    # Decoder Network
    decoder = models.Sequential(name='decoder')
    decoder.add(layers.Dense(input_dim=digit_caps_dim_vector, activation="relu", output_dim=7*7*digit_caps_dim_vector, name='dense1'))
    decoder.add(layers.Reshape((7, 7, digit_caps_dim_vector)))
    decoder.add(layers.BatchNormalization(name='batch_norm2'))
    decoder.add(layers.Deconvolution2D(64, 3, 3, subsample=(1, 1), border_mode='same', name='deconv1'))
    decoder.add(layers.Deconvolution2D(32, 3, 3, subsample=(2, 2), border_mode='same', name='deconv2'))
    decoder.add(layers.Deconvolution2D(16, 3, 3, subsample=(2, 2), border_mode='same', name='deconv3'))
    decoder.add(layers.Deconvolution2D(1, 3, 3, subsample=(1, 1), border_mode='same', name='deconv4'))
    decoder.add(layers.Activation("relu"))
    decoder.add(layers.Reshape(target_shape=input_shape, name='out_recon'))

    # plot the decoder/reconstruction network
    try:
      plot_model(decoder, to_file='decoder.png', show_shapes=True)
    except Exception as e:
      print('No fancy plot {}'.format(e))

    # create model used for training/inference/prediction
    # two-input-two-output keras Model
    train_model = models.Model([x, y], [out_caps, decoder(masked)])

    # create model to manipulate fed digit to visualise the effect of a caps dimension on the reconstruction
    # three-input-one-output keras Model; input: (image, mask, noise)
    noise = layers.Input(shape=(n_class, digit_caps_dim_vector))
    noise_plus_digitcaps = layers.Add()([digitcaps, noise])
    masked_noised_y = Mask()([noise_plus_digitcaps, y]) # masked the noised digitcaps with input
    manip_model = models.Model([x, y, noise], decoder(masked_noised_y))

    return train_model, manip_model

# %% [markdown]
# # Margin Loss

# %% [markdown]
# Use custom margin loss as proposed in the original paper for gradient updates

# %%
def margin_loss(y_true, y_pred):
    """
    Margin loss for Eq.(4). When y_true[i, :] contains not just one `1`, this loss should work too. Not test it.
    :param y_true: [None, n_classes]
    :param y_pred: [None, num_capsule]
    :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %% [markdown]
# # Load Data

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import gzip


def load_data():
    """Loads the Kannada-MNIST dataset.
    # Returns
        Tuple of Numpy arrays: `(x_train, y_train), (x_test, y_test)`.
    """
    dirname = os.path.join('datasets', 'Kannada-mnist')
    base = 'https://github.com/vinayprabhu/Kannada_MNIST/blob/master/data/output_tensors/MNIST_format/'
    files = ['y_kannada_MNIST_train-idx1-ubyte.gz', 'X_kannada_MNIST_train-idx3-ubyte.gz',
             'y_kannada_MNIST_test-idx1-ubyte.gz', 'X_kannada_MNIST_test-idx3-ubyte.gz',
             'y_dig_MNIST-idx1-ubyte.gz', 'X_dig_MNIST-idx3-ubyte.gz']

    paths = []
    for fname in files:
        paths.append(get_file(fname,
                              origin=base + fname+'?raw=true',
                              cache_subdir=dirname))

    with gzip.open(paths[0], 'rb') as lbpath:
        y_train = np.frombuffer(lbpath.read(), np.uint8, offset=8)

    with gzip.open(paths[1], 'rb') as imgpath:
        x_train = np.frombuffer(imgpath.read(), np.uint8,
                                offset=16).reshape(len(y_train), 28, 28)

    with gzip.open(paths[2], 'rb') as lbpath:
        y_test = np.frombuffer(lbpath.read(), np.uint8, offset=8)

    with gzip.open(paths[3], 'rb') as imgpath:
        x_test = np.frombuffer(imgpath.read(), np.uint8,
                               offset=16).reshape(len(y_test), 28, 28)
    
    with gzip.open(paths[2], 'rb') as lbpath:
        y_dig = np.frombuffer(lbpath.read(), np.uint8, offset=8)

    with gzip.open(paths[5], 'rb') as imgpath:
        x_dig = np.frombuffer(imgpath.read(), np.uint8,
                               offset=16).reshape(10240, 28, 28)                               

    return (x_train, y_train), (x_test, y_test), (x_dig, y_dig)

# %%
(train_images, train_labels), (test_images, test_labels), (dig_images, dig_labels) = load_data()
print(f'Training set images: {train_images.shape}')
print(f'Testing set images: {test_images.shape}')
print(f'DIG-10K set images: {dig_images.shape}')
# Out:
# Downloading data from https://github.com/vinayprabhu/Kannada_MNIST/blob/master/data/output_tensors/MNIST_format/y_kannada_MNIST_train-idx1-ubyte.gz?raw=true
# 8192/199 [==================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================] - 0s 0us/step
# Downloading data from https://github.com/vinayprabhu/Kannada_MNIST/blob/master/data/output_tensors/MNIST_format/X_kannada_MNIST_train-idx3-ubyte.gz?raw=true
# 6922240/6918402 [==============================] - 0s 0us/step
# Downloading data from https://github.com/vinayprabhu/Kannada_MNIST/blob/master/data/output_tensors/MNIST_format/y_kannada_MNIST_test-idx1-ubyte.gz?raw=true
# 8192/103 [==================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================] - 0s 0us/step
# Downloading data from https://github.com/vinayprabhu/Kannada_MNIST/blob/master/data/output_tensors/MNIST_format/X_kannada_MNIST_test-idx3-ubyte.gz?raw=true
# 1122304/1120203 [==============================] - 0s 0us/step
# Downloading data from https://github.com/vinayprabhu/Kannada_MNIST/blob/master/data/output_tensors/MNIST_format/y_dig_MNIST-idx1-ubyte.gz?raw=true
# 8192/92 [===============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================] - 0s 0us/step
# Downloading data from https://github.com/vinayprabhu/Kannada_MNIST/blob/master/data/output_tensors/MNIST_format/X_dig_MNIST-idx3-ubyte.gz?raw=true
# 1400832/1395287 [==============================] - 0s 0us/step
# Training set images: (60000, 28, 28)
# Testing set images: (10000, 28, 28)
# DIG-10K set images: (10240, 28, 28)

# %% [markdown]
# Normalise the image data and one-hot encode the targets/labels

# %%
train_images = train_images.reshape((-1, 28, 28, 1)).astype('float32') / 255.
test_images = test_images.reshape((-1, 28, 28, 1)).astype('float32') / 255.
dig_images = dig_images.reshape((-1, 28, 28, 1)).astype('float32') / 255.

train_labels = to_categorical(train_labels.astype('float32'))
test_labels = to_categorical(test_labels.astype('float32'))
dig_labels = to_categorical(dig_labels.astype('float32'))

# %% [markdown]
# Train-Validation spilt(90%-10%)

# %%
val_images = train_images[54000:]
val_labels = train_labels[54000:]

train_images = train_images[:54000]
train_labels = train_labels[:54000]

# %%
print("Training images: ", train_images.shape)
# print(type(train_images))

print("Validation images: ", val_images.shape)
# print(type(val_images))

print("Testing images: ", test_images.shape)
# print(type(test_images))

print("DIG-10K: ", dig_images.shape)
# print(type(dig_images))

# Aliasing for conventions
x_train = train_images
y_train = train_labels

x_val = val_images
y_val = val_labels

x_test = test_images
y_test = test_labels

x_dig = dig_images
y_dig = dig_labels
# Out:
# Training images:  (54000, 28, 28, 1)
# Validation images:  (6000, 28, 28, 1)
# Testing images:  (10000, 28, 28, 1)
# DIG-10K:  (10240, 28, 28, 1)

# %% [markdown]
# Visualise a few samples from each of the datasets

# %%
# custom util function for visualisation of the input images
def input_viz(data, title, num_row=5, num_col=10, facecolor='xkcd:ecru'):
  x, y = data
  num = num_row*num_col
  images = x[:num]
  labels = y[:num]
  
  fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row), facecolor=facecolor)
  fig.suptitle(title, fontsize=18, fontweight='bold')
  for i in range(num):
      ax = axes[i//num_col, i%num_col]
      ax.imshow(images[i].reshape((28, 28)), cmap='gray')
      ax.set_title(f'Number: {np.argmax(labels[i])}', fontsize=12)
      ax.axis('Off')
  plt.tight_layout(pad=2.0)
  plt.show()

# %%
input_viz((x_train, y_train), 'Train set')

# %%
input_viz((x_val, y_val), 'Validation set')

# %%
input_viz((x_test, y_test), 'Test set')

# %%
input_viz((x_dig, y_dig), 'DIG-10K set')

# %% [markdown]
# # Instantiate the model

# %% [markdown]
# Define the hyperparameters

# %%
class args:
  routings = 3 # number of iterations of the dynamic routing algorithm between 2 capsule layers
  digit_caps_dim_vector = 32 # number of capsules in the "digit-caps" layer OR the dimensionality of the output vectors of the digit caps layer
  batch_size = 128
  epochs = 70
  recon_loss_weight = 0.0005
  lr = 0.001

# %%
input_shape = x_train.shape[1:] # for kannada mnist, mnist: (28, 28, 1)
num_classes = len(np.unique(np.argmax(y_train, 1))) # for kannada mnist, mnist: 10

# define model
model, manip_model = CapsNet(input_shape=input_shape,
                             n_class=num_classes,
                             num_routing=args.routings,
                             digit_caps_dim_vector=args.digit_caps_dim_vector)
model.summary()

try:
    plot_model(model, to_file='model.png', show_shapes=True)
except Exception as e:
    print('No fancy plot {}'.format(e))
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 20, 20, 256)  20992       input_4[0][0]
# __________________________________________________________________________________________________
# batch_norm1 (BatchNormalization (None, 20, 20, 256)  1024        conv1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 6, 6, 256)    5308672     batch_norm1[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1152, 8)      0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1152, 8)      0           reshape_3[0][0]
# __________________________________________________________________________________________________
# digit_caps (CapsuleLayer)       (None, 10, 32)       2960640     lambda_2[0][0]
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 10)           0
# __________________________________________________________________________________________________
# mask_3 (Mask)                   (None, 32)           0           digit_caps[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# out_caps (Length)               (None, 10)           0           digit_caps[0][0]
# __________________________________________________________________________________________________
# decoder (Sequential)            (None, 28, 28, 1)    93601       mask_3[0][0]
# ==================================================================================================
# Total params: 8,384,929
# Trainable params: 8,372,833
# Non-trainable params: 12,096
# __________________________________________________________________________________________________

# %% [markdown]
# # Train the network

# %%
"""
the original research paper proposes using a SSE loss with a weight of 0.0005
that is equivalent to using the mean loss (MSE) and then multiply it by the total
values being output in the final layer
(sum = number of instances * mean)
"""
recon_lambda = args.recon_loss_weight*np.prod(input_shape)

# %%
from keras.preprocessing.image import ImageDataGenerator

def train(model, data):
    """
    Training a CapsuleNet
    :param model: the CapsuleNet model
    :param data: a tuple containing training and testing data, like `((x_train, y_train), (x_test, y_test))`
    :param args: arguments
    :return: The trained model
    """
    # unpacking the data
    (x_train, y_train), (x_val, y_val) = data

    # callbacks
    log = callbacks.CSVLogger('log.csv')
    checkpoint = callbacks.ModelCheckpoint('weights-{epoch:02d}.h5', save_best_only=True, save_weights_only=True, verbose=1)
    lr_decay = callbacks.LearningRateScheduler(schedule=lambda epoch: args.lr * np.exp(-epoch / 10.))

    # compile the model
    opt = 'nadam'
    model.compile(optimizer=opt,
                  loss=[margin_loss, 'mse'], # use MSE loss metric for the reconstruction network
                  loss_weights=[1., recon_lambda],
                  metrics={'out_caps': 'accuracy'})

    # Training without data augmentation:
    # history = model.fit([x_train, y_train], [y_train, x_train], batch_size=args.batch_size, epochs=args.epochs,
    #           validation_data=[[x_val, y_val], [y_val, x_val]], callbacks=[lr_decay, checkpoint, log])

    # Begin: Training with data augmentation ---------------------------------------------------------------------#
    def train_generator(x, y, batch_size, shift_fraction=0.2):
        train_datagen = ImageDataGenerator(width_shift_range=shift_fraction,
                                           height_shift_range=shift_fraction,  # shift up to 2 pixel for MNIST
                                           zca_whitening=True,
                                           rotation_range=20,
                                           zoom_range=0.2,
                                           shear_range=0.2)
        generator = train_datagen.flow(x, y, batch_size=args.batch_size)
        while 1:
            x_batch, y_batch = generator.next()
            yield ([x_batch, y_batch], [y_batch, x_batch])

    # Training with data augmentation. If shift_fraction=0., also no augmentation.
    model.fit_generator(generator=train_generator(x_train, y_train, args.batch_size, 0.2),
                        steps_per_epoch=int(y_train.shape[0]/args.batch_size),
                        epochs=args.epochs,
                        validation_data=[[x_val, y_val], [y_val, x_val]], callbacks=[lr_decay, checkpoint, log])
    # End: Training with data augmentation -----------------------------------------------------------------------#

    model.save_weights('trained_model.h5')
    print('Trained model saved to \'trained_model.h5\'')

    return model

# %%
train(model=model, data=((x_train, y_train), (x_val, y_val)))
# Out:
# Epoch 1/70
# 421/421 [==============================] - 255s 605ms/step - loss: 0.1223 - out_caps_loss: 0.1101 - decoder_loss: 0.0311 - out_caps_acc: 0.8973 - val_loss: 0.0396 - val_out_caps_loss: 0.0245 - val_decoder_loss: 0.0385 - val_out_caps_acc: 0.9877
#
# Epoch 00001: val_loss improved from inf to 0.03956, saving model to weights-01.h5
# Epoch 2/70
# 421/421 [==============================] - 256s 609ms/step - loss: 0.0467 - out_caps_loss: 0.0363 - decoder_loss: 0.0265 - out_caps_acc: 0.9767 - val_loss: 0.0309 - val_out_caps_loss: 0.0170 - val_decoder_loss: 0.0354 - val_out_caps_acc: 0.9920
#
# Epoch 00002: val_loss improved from 0.03956 to 0.03090, saving model to weights-02.h5
# Epoch 3/70
# 421/421 [==============================] - 252s 599ms/step - loss: 0.0359 - out_caps_loss: 0.0266 - decoder_loss: 0.0238 - out_caps_acc: 0.9815 - val_loss: 0.0265 - val_out_caps_loss: 0.0135 - val_decoder_loss: 0.0332 - val_out_caps_acc: 0.9947
#
# Epoch 00003: val_loss improved from 0.03090 to 0.02654, saving model to weights-03.h5
# Epoch 4/70
# 421/421 [==============================] - 251s 596ms/step - loss: 0.0310 - out_caps_loss: 0.0222 - decoder_loss: 0.0222 - out_caps_acc: 0.9850 - val_loss: 0.0208 - val_out_caps_loss: 0.0085 - val_decoder_loss: 0.0312 - val_out_caps_acc: 0.9955
#
# Epoch 00004: val_loss improved from 0.02654 to 0.02076, saving model to weights-04.h5
# Epoch 5/70
# 421/421 [==============================] - 254s 603ms/step - loss: 0.0269 - out_caps_loss: 0.0187 - decoder_loss: 0.0210 - out_caps_acc: 0.9868 - val_loss: 0.0233 - val_out_caps_loss: 0.0115 - val_decoder_loss: 0.0302 - val_out_caps_acc: 0.9942
#
# Epoch 00005: val_loss did not improve from 0.02076
# Epoch 6/70
# 421/421 [==============================] - 255s 605ms/step - loss: 0.0248 - out_caps_loss: 0.0170 - decoder_loss: 0.0200 - out_caps_acc: 0.9875 - val_loss: 0.0191 - val_out_caps_loss: 0.0076 - val_decoder_loss: 0.0294 - val_out_caps_acc: 0.9958
#
# Epoch 00006: val_loss improved from 0.02076 to 0.01911, saving model to weights-06.h5
# Epoch 7/70
# 421/421 [==============================] - 251s 596ms/step - loss: 0.0228 - out_caps_loss: 0.0152 - decoder_loss: 0.0193 - out_caps_acc: 0.9890 - val_loss: 0.0192 - val_out_caps_loss: 0.0079 - val_decoder_loss: 0.0287 - val_out_caps_acc: 0.9942
#
# Epoch 00007: val_loss did not improve from 0.01911
# Epoch 8/70
# 421/421 [==============================] - 251s 597ms/step - loss: 0.0214 - out_caps_loss: 0.0141 - decoder_loss: 0.0187 - out_caps_acc: 0.9895 - val_loss: 0.0173 - val_out_caps_loss: 0.0065 - val_decoder_loss: 0.0276 - val_out_caps_acc: 0.9962
#
# Epoch 00008: val_loss improved from 0.01911 to 0.01733, saving model to weights-08.h5
# Epoch 9/70
# 421/421 [==============================] - 257s 610ms/step - loss: 0.0200 - out_caps_loss: 0.0129 - decoder_loss: 0.0181 - out_caps_acc: 0.9900 - val_loss: 0.0195 - val_out_caps_loss: 0.0090 - val_decoder_loss: 0.0269 - val_out_caps_acc: 0.9950
#
# Epoch 00009: val_loss did not improve from 0.01733
# Epoch 10/70
# 421/421 [==============================] - 253s 601ms/step - loss: 0.0190 - out_caps_loss: 0.0120 - decoder_loss: 0.0176 - out_caps_acc: 0.9905 - val_loss: 0.0150 - val_out_caps_loss: 0.0046 - val_decoder_loss: 0.0266 - val_out_caps_acc: 0.9970
#
# Epoch 00010: val_loss improved from 0.01733 to 0.01504, saving model to weights-10.h5
# Epoch 11/70
# 421/421 [==============================] - 257s 610ms/step - loss: 0.0183 - out_caps_loss: 0.0115 - decoder_loss: 0.0173 - out_caps_acc: 0.9902 - val_loss: 0.0156 - val_out_caps_loss: 0.0054 - val_decoder_loss: 0.0260 - val_out_caps_acc: 0.9958
#
# Epoch 00011: val_loss did not improve from 0.01504
# Epoch 12/70
# 421/421 [==============================] - 263s 625ms/step - loss: 0.0177 - out_caps_loss: 0.0111 - decoder_loss: 0.0169 - out_caps_acc: 0.9904 - val_loss: 0.0149 - val_out_caps_loss: 0.0050 - val_decoder_loss: 0.0254 - val_out_caps_acc: 0.9958
#
# Epoch 00012: val_loss improved from 0.01504 to 0.01490, saving model to weights-12.h5
# Epoch 13/70
# 421/421 [==============================] - 253s 602ms/step - loss: 0.0169 - out_caps_loss: 0.0104 - decoder_loss: 0.0166 - out_caps_acc: 0.9909 - val_loss: 0.0152 - val_out_caps_loss: 0.0053 - val_decoder_loss: 0.0252 - val_out_caps_acc: 0.9962
#
# Epoch 00013: val_loss did not improve from 0.01490
# Epoch 14/70
# 421/421 [==============================] - 252s 598ms/step - loss: 0.0161 - out_caps_loss: 0.0098 - decoder_loss: 0.0162 - out_caps_acc: 0.9917 - val_loss: 0.0140 - val_out_caps_loss: 0.0043 - val_decoder_loss: 0.0248 - val_out_caps_acc: 0.9970
#
# Epoch 00014: val_loss improved from 0.01490 to 0.01399, saving model to weights-14.h5
# Epoch 15/70
# 421/421 [==============================] - 254s 604ms/step - loss: 0.0157 - out_caps_loss: 0.0094 - decoder_loss: 0.0160 - out_caps_acc: 0.9922 - val_loss: 0.0142 - val_out_caps_loss: 0.0047 - val_decoder_loss: 0.0243 - val_out_caps_acc: 0.9972
#
# Epoch 00015: val_loss did not improve from 0.01399
# Epoch 16/70
# 421/421 [==============================] - 256s 609ms/step - loss: 0.0150 - out_caps_loss: 0.0088 - decoder_loss: 0.0157 - out_caps_acc: 0.9923 - val_loss: 0.0147 - val_out_caps_loss: 0.0052 - val_decoder_loss: 0.0243 - val_out_caps_acc: 0.9955
#
# Epoch 00016: val_loss did not improve from 0.01399
# Epoch 17/70
# 421/421 [==============================] - 252s 598ms/step - loss: 0.0144 - out_caps_loss: 0.0083 - decoder_loss: 0.0155 - out_caps_acc: 0.9926 - val_loss: 0.0142 - val_out_caps_loss: 0.0047 - val_decoder_loss: 0.0241 - val_out_caps_acc: 0.9963
#
# Epoch 00017: val_loss did not improve from 0.01399
# Epoch 18/70
# 421/421 [==============================] - 252s 599ms/step - loss: 0.0143 - out_caps_loss: 0.0083 - decoder_loss: 0.0153 - out_caps_acc: 0.9928 - val_loss: 0.0136 - val_out_caps_loss: 0.0043 - val_decoder_loss: 0.0235 - val_out_caps_acc: 0.9962
#
# Epoch 00018: val_loss improved from 0.01399 to 0.01356, saving model to weights-18.h5
# Epoch 19/70
# 421/421 [==============================] - 258s 612ms/step - loss: 0.0138 - out_caps_loss: 0.0079 - decoder_loss: 0.0150 - out_caps_acc: 0.9925 - val_loss: 0.0154 - val_out_caps_loss: 0.0062 - val_decoder_loss: 0.0234 - val_out_caps_acc: 0.9948
#
# Epoch 00019: val_loss did not improve from 0.01356
# Epoch 20/70
# 421/421 [==============================] - 252s 600ms/step - loss: 0.0134 - out_caps_loss: 0.0076 - decoder_loss: 0.0149 - out_caps_acc: 0.9931 - val_loss: 0.0131 - val_out_caps_loss: 0.0040 - val_decoder_loss: 0.0233 - val_out_caps_acc: 0.9967
#
# Epoch 00020: val_loss improved from 0.01356 to 0.01314, saving model to weights-20.h5
# Epoch 21/70
# 421/421 [==============================] - 252s 599ms/step - loss: 0.0133 - out_caps_loss: 0.0076 - decoder_loss: 0.0147 - out_caps_acc: 0.9932 - val_loss: 0.0137 - val_out_caps_loss: 0.0047 - val_decoder_loss: 0.0230 - val_out_caps_acc: 0.9963
#
# Epoch 00021: val_loss did not improve from 0.01314
# Epoch 22/70
# 421/421 [==============================] - 257s 610ms/step - loss: 0.0128 - out_caps_loss: 0.0071 - decoder_loss: 0.0145 - out_caps_acc: 0.9934 - val_loss: 0.0134 - val_out_caps_loss: 0.0045 - val_decoder_loss: 0.0229 - val_out_caps_acc: 0.9958
#
# Epoch 00022: val_loss did not improve from 0.01314
# Epoch 23/70
# 421/421 [==============================] - 251s 597ms/step - loss: 0.0125 - out_caps_loss: 0.0068 - decoder_loss: 0.0144 - out_caps_acc: 0.9938 - val_loss: 0.0131 - val_out_caps_loss: 0.0042 - val_decoder_loss: 0.0227 - val_out_caps_acc: 0.9960
#
# Epoch 00023: val_loss improved from 0.01314 to 0.01310, saving model to weights-23.h5
# Epoch 24/70
# 421/421 [==============================] - 252s 599ms/step - loss: 0.0124 - out_caps_loss: 0.0068 - decoder_loss: 0.0143 - out_caps_acc: 0.9936 - val_loss: 0.0131 - val_out_caps_loss: 0.0042 - val_decoder_loss: 0.0228 - val_out_caps_acc: 0.9968
#
# Epoch 00024: val_loss did not improve from 0.01310
# Epoch 25/70
# 421/421 [==============================] - 257s 611ms/step - loss: 0.0120 - out_caps_loss: 0.0065 - decoder_loss: 0.0142 - out_caps_acc: 0.9940 - val_loss: 0.0128 - val_out_caps_loss: 0.0041 - val_decoder_loss: 0.0223 - val_out_caps_acc: 0.9965
#
# Epoch 00025: val_loss improved from 0.01310 to 0.01281, saving model to weights-25.h5
# Epoch 26/70
# 421/421 [==============================] - 253s 600ms/step - loss: 0.0117 - out_caps_loss: 0.0062 - decoder_loss: 0.0140 - out_caps_acc: 0.9943 - val_loss: 0.0125 - val_out_caps_loss: 0.0038 - val_decoder_loss: 0.0221 - val_out_caps_acc: 0.9965
#
# Epoch 00026: val_loss improved from 0.01281 to 0.01251, saving model to weights-26.h5
# Epoch 27/70
# 421/421 [==============================] - 252s 599ms/step - loss: 0.0118 - out_caps_loss: 0.0063 - decoder_loss: 0.0140 - out_caps_acc: 0.9938 - val_loss: 0.0133 - val_out_caps_loss: 0.0046 - val_decoder_loss: 0.0222 - val_out_caps_acc: 0.9962
#
# Epoch 00027: val_loss did not improve from 0.01251
# Epoch 28/70
# 421/421 [==============================] - 257s 611ms/step - loss: 0.0112 - out_caps_loss: 0.0058 - decoder_loss: 0.0138 - out_caps_acc: 0.9946 - val_loss: 0.0125 - val_out_caps_loss: 0.0039 - val_decoder_loss: 0.0220 - val_out_caps_acc: 0.9958
#
# Epoch 00028: val_loss did not improve from 0.01251
# Epoch 29/70
# 421/421 [==============================] - 254s 602ms/step - loss: 0.0115 - out_caps_loss: 0.0061 - decoder_loss: 0.0138 - out_caps_acc: 0.9942 - val_loss: 0.0127 - val_out_caps_loss: 0.0041 - val_decoder_loss: 0.0220 - val_out_caps_acc: 0.9953
#
# Epoch 00029: val_loss did not improve from 0.01251
# Epoch 30/70
# 421/421 [==============================] - 253s 600ms/step - loss: 0.0109 - out_caps_loss: 0.0055 - decoder_loss: 0.0136 - out_caps_acc: 0.9947 - val_loss: 0.0126 - val_out_caps_loss: 0.0040 - val_decoder_loss: 0.0219 - val_out_caps_acc: 0.9962
#
# Epoch 00030: val_loss did not improve from 0.01251
# Epoch 31/70
# 421/421 [==============================] - 257s 612ms/step - loss: 0.0113 - out_caps_loss: 0.0059 - decoder_loss: 0.0136 - out_caps_acc: 0.9942 - val_loss: 0.0122 - val_out_caps_loss: 0.0037 - val_decoder_loss: 0.0217 - val_out_caps_acc: 0.9967
#
# Epoch 00031: val_loss improved from 0.01251 to 0.01220, saving model to weights-31.h5
# Epoch 32/70
# 421/421 [==============================] - 254s 604ms/step - loss: 0.0108 - out_caps_loss: 0.0055 - decoder_loss: 0.0135 - out_caps_acc: 0.9947 - val_loss: 0.0124 - val_out_caps_loss: 0.0040 - val_decoder_loss: 0.0216 - val_out_caps_acc: 0.9960
#
# Epoch 00032: val_loss did not improve from 0.01220
# Epoch 33/70
# 421/421 [==============================] - 253s 600ms/step - loss: 0.0105 - out_caps_loss: 0.0053 - decoder_loss: 0.0134 - out_caps_acc: 0.9950 - val_loss: 0.0127 - val_out_caps_loss: 0.0042 - val_decoder_loss: 0.0217 - val_out_caps_acc: 0.9955
#
# Epoch 00033: val_loss did not improve from 0.01220
# Epoch 34/70
# 421/421 [==============================] - 253s 600ms/step - loss: 0.0108 - out_caps_loss: 0.0055 - decoder_loss: 0.0134 - out_caps_acc: 0.9944 - val_loss: 0.0122 - val_out_caps_loss: 0.0037 - val_decoder_loss: 0.0216 - val_out_caps_acc: 0.9962
#
# Epoch 00034: val_loss did not improve from 0.01220
# Epoch 35/70
# 421/421 [==============================] - 252s 599ms/step - loss: 0.0103 - out_caps_loss: 0.0051 - decoder_loss: 0.0133 - out_caps_acc: 0.9948 - val_loss: 0.0118 - val_out_caps_loss: 0.0034 - val_decoder_loss: 0.0215 - val_out_caps_acc: 0.9963
#
# Epoch 00035: val_loss improved from 0.01220 to 0.01181, saving model to weights-35.h5
# Epoch 36/70
# 421/421 [==============================] - 253s 601ms/step - loss: 0.0105 - out_caps_loss: 0.0053 - decoder_loss: 0.0133 - out_caps_acc: 0.9947 - val_loss: 0.0125 - val_out_caps_loss: 0.0041 - val_decoder_loss: 0.0214 - val_out_caps_acc: 0.9955
#
# Epoch 00036: val_loss did not improve from 0.01181
# Epoch 37/70
# 421/421 [==============================] - 256s 607ms/step - loss: 0.0106 - out_caps_loss: 0.0054 - decoder_loss: 0.0132 - out_caps_acc: 0.9944 - val_loss: 0.0122 - val_out_caps_loss: 0.0038 - val_decoder_loss: 0.0213 - val_out_caps_acc: 0.9960
#
# Epoch 00037: val_loss did not improve from 0.01181
# Epoch 38/70
# 421/421 [==============================] - 254s 602ms/step - loss: 0.0104 - out_caps_loss: 0.0052 - decoder_loss: 0.0132 - out_caps_acc: 0.9949 - val_loss: 0.0121 - val_out_caps_loss: 0.0037 - val_decoder_loss: 0.0214 - val_out_caps_acc: 0.9962
#
# Epoch 00038: val_loss did not improve from 0.01181
# Epoch 39/70
# 421/421 [==============================] - 251s 597ms/step - loss: 0.0100 - out_caps_loss: 0.0048 - decoder_loss: 0.0132 - out_caps_acc: 0.9954 - val_loss: 0.0121 - val_out_caps_loss: 0.0038 - val_decoder_loss: 0.0212 - val_out_caps_acc: 0.9958
#
# Epoch 00039: val_loss did not improve from 0.01181
# Epoch 40/70
# 421/421 [==============================] - 251s 595ms/step - loss: 0.0102 - out_caps_loss: 0.0051 - decoder_loss: 0.0131 - out_caps_acc: 0.9947 - val_loss: 0.0121 - val_out_caps_loss: 0.0038 - val_decoder_loss: 0.0212 - val_out_caps_acc: 0.9963
#
# Epoch 00040: val_loss did not improve from 0.01181
# Epoch 41/70
# 421/421 [==============================] - 251s 595ms/step - loss: 0.0100 - out_caps_loss: 0.0049 - decoder_loss: 0.0131 - out_caps_acc: 0.9950 - val_loss: 0.0117 - val_out_caps_loss: 0.0034 - val_decoder_loss: 0.0212 - val_out_caps_acc: 0.9963
#
# Epoch 00041: val_loss improved from 0.01181 to 0.01170, saving model to weights-41.h5
# Epoch 42/70
# 421/421 [==============================] - 252s 598ms/step - loss: 0.0101 - out_caps_loss: 0.0050 - decoder_loss: 0.0131 - out_caps_acc: 0.9950 - val_loss: 0.0118 - val_out_caps_loss: 0.0035 - val_decoder_loss: 0.0212 - val_out_caps_acc: 0.9963
#
# Epoch 00042: val_loss did not improve from 0.01170
# Epoch 43/70
# 421/421 [==============================] - 256s 609ms/step - loss: 0.0100 - out_caps_loss: 0.0049 - decoder_loss: 0.0130 - out_caps_acc: 0.9951 - val_loss: 0.0117 - val_out_caps_loss: 0.0034 - val_decoder_loss: 0.0211 - val_out_caps_acc: 0.9960
#
# Epoch 00043: val_loss improved from 0.01170 to 0.01169, saving model to weights-43.h5
# Epoch 44/70
# 421/421 [==============================] - 253s 601ms/step - loss: 0.0100 - out_caps_loss: 0.0049 - decoder_loss: 0.0130 - out_caps_acc: 0.9951 - val_loss: 0.0119 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0211 - val_out_caps_acc: 0.9962
#
# Epoch 00044: val_loss did not improve from 0.01169
# Epoch 45/70
# 421/421 [==============================] - 253s 600ms/step - loss: 0.0098 - out_caps_loss: 0.0047 - decoder_loss: 0.0130 - out_caps_acc: 0.9953 - val_loss: 0.0118 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0211 - val_out_caps_acc: 0.9963
#
# Epoch 00045: val_loss did not improve from 0.01169
# Epoch 46/70
# 421/421 [==============================] - 254s 603ms/step - loss: 0.0097 - out_caps_loss: 0.0047 - decoder_loss: 0.0130 - out_caps_acc: 0.9952 - val_loss: 0.0119 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0211 - val_out_caps_acc: 0.9962
#
# Epoch 00046: val_loss did not improve from 0.01169
# Epoch 47/70
# 421/421 [==============================] - 256s 608ms/step - loss: 0.0098 - out_caps_loss: 0.0047 - decoder_loss: 0.0130 - out_caps_acc: 0.9953 - val_loss: 0.0117 - val_out_caps_loss: 0.0034 - val_decoder_loss: 0.0210 - val_out_caps_acc: 0.9962
#
# Epoch 00047: val_loss improved from 0.01169 to 0.01168, saving model to weights-47.h5
# Epoch 48/70
# 421/421 [==============================] - 251s 597ms/step - loss: 0.0096 - out_caps_loss: 0.0045 - decoder_loss: 0.0129 - out_caps_acc: 0.9958 - val_loss: 0.0116 - val_out_caps_loss: 0.0034 - val_decoder_loss: 0.0210 - val_out_caps_acc: 0.9965
#
# Epoch 00048: val_loss improved from 0.01168 to 0.01159, saving model to weights-48.h5
# Epoch 49/70
# 421/421 [==============================] - 251s 596ms/step - loss: 0.0099 - out_caps_loss: 0.0048 - decoder_loss: 0.0129 - out_caps_acc: 0.9950 - val_loss: 0.0119 - val_out_caps_loss: 0.0037 - val_decoder_loss: 0.0210 - val_out_caps_acc: 0.9962
#
# Epoch 00049: val_loss did not improve from 0.01159
# Epoch 50/70
# 421/421 [==============================] - 250s 595ms/step - loss: 0.0099 - out_caps_loss: 0.0049 - decoder_loss: 0.0129 - out_caps_acc: 0.9950 - val_loss: 0.0119 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0210 - val_out_caps_acc: 0.9962
#
# Epoch 00050: val_loss did not improve from 0.01159
# Epoch 51/70
# 421/421 [==============================] - 252s 598ms/step - loss: 0.0098 - out_caps_loss: 0.0048 - decoder_loss: 0.0129 - out_caps_acc: 0.9954 - val_loss: 0.0119 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00051: val_loss did not improve from 0.01159
# Epoch 52/70
# 421/421 [==============================] - 256s 608ms/step - loss: 0.0096 - out_caps_loss: 0.0046 - decoder_loss: 0.0129 - out_caps_acc: 0.9949 - val_loss: 0.0117 - val_out_caps_loss: 0.0035 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00052: val_loss did not improve from 0.01159
# Epoch 53/70
# 421/421 [==============================] - 252s 598ms/step - loss: 0.0096 - out_caps_loss: 0.0045 - decoder_loss: 0.0129 - out_caps_acc: 0.9952 - val_loss: 0.0119 - val_out_caps_loss: 0.0037 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00053: val_loss did not improve from 0.01159
# Epoch 54/70
# 421/421 [==============================] - 253s 601ms/step - loss: 0.0100 - out_caps_loss: 0.0049 - decoder_loss: 0.0129 - out_caps_acc: 0.9949 - val_loss: 0.0118 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00054: val_loss did not improve from 0.01159
# Epoch 55/70
# 421/421 [==============================] - 255s 606ms/step - loss: 0.0097 - out_caps_loss: 0.0047 - decoder_loss: 0.0128 - out_caps_acc: 0.9951 - val_loss: 0.0119 - val_out_caps_loss: 0.0037 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00055: val_loss did not improve from 0.01159
# Epoch 56/70
# 421/421 [==============================] - 254s 604ms/step - loss: 0.0097 - out_caps_loss: 0.0047 - decoder_loss: 0.0129 - out_caps_acc: 0.9950 - val_loss: 0.0118 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00056: val_loss did not improve from 0.01159
# Epoch 57/70
# 421/421 [==============================] - 251s 597ms/step - loss: 0.0096 - out_caps_loss: 0.0046 - decoder_loss: 0.0128 - out_caps_acc: 0.9955 - val_loss: 0.0118 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00057: val_loss did not improve from 0.01159
# Epoch 58/70
# 421/421 [==============================] - 251s 595ms/step - loss: 0.0096 - out_caps_loss: 0.0045 - decoder_loss: 0.0128 - out_caps_acc: 0.9952 - val_loss: 0.0118 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00058: val_loss did not improve from 0.01159
# Epoch 59/70
# 421/421 [==============================] - 251s 595ms/step - loss: 0.0097 - out_caps_loss: 0.0046 - decoder_loss: 0.0128 - out_caps_acc: 0.9952 - val_loss: 0.0117 - val_out_caps_loss: 0.0035 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00059: val_loss did not improve from 0.01159
# Epoch 60/70
# 421/421 [==============================] - 251s 597ms/step - loss: 0.0095 - out_caps_loss: 0.0045 - decoder_loss: 0.0128 - out_caps_acc: 0.9954 - val_loss: 0.0117 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00060: val_loss did not improve from 0.01159
# Epoch 61/70
# 421/421 [==============================] - 255s 606ms/step - loss: 0.0097 - out_caps_loss: 0.0047 - decoder_loss: 0.0128 - out_caps_acc: 0.9953 - val_loss: 0.0118 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00061: val_loss did not improve from 0.01159
# Epoch 62/70
# 421/421 [==============================] - 251s 597ms/step - loss: 0.0096 - out_caps_loss: 0.0046 - decoder_loss: 0.0128 - out_caps_acc: 0.9954 - val_loss: 0.0118 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00062: val_loss did not improve from 0.01159
# Epoch 63/70
# 421/421 [==============================] - 253s 600ms/step - loss: 0.0095 - out_caps_loss: 0.0045 - decoder_loss: 0.0128 - out_caps_acc: 0.9957 - val_loss: 0.0118 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00063: val_loss did not improve from 0.01159
# Epoch 64/70
# 421/421 [==============================] - 253s 602ms/step - loss: 0.0098 - out_caps_loss: 0.0047 - decoder_loss: 0.0128 - out_caps_acc: 0.9951 - val_loss: 0.0118 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00064: val_loss did not improve from 0.01159
# Epoch 65/70
# 421/421 [==============================] - 258s 613ms/step - loss: 0.0097 - out_caps_loss: 0.0047 - decoder_loss: 0.0128 - out_caps_acc: 0.9948 - val_loss: 0.0118 - val_out_caps_loss: 0.0037 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00065: val_loss did not improve from 0.01159
# Epoch 66/70
# 421/421 [==============================] - 253s 600ms/step - loss: 0.0097 - out_caps_loss: 0.0046 - decoder_loss: 0.0128 - out_caps_acc: 0.9953 - val_loss: 0.0118 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00066: val_loss did not improve from 0.01159
# Epoch 67/70
# 421/421 [==============================] - 251s 596ms/step - loss: 0.0095 - out_caps_loss: 0.0045 - decoder_loss: 0.0128 - out_caps_acc: 0.9955 - val_loss: 0.0118 - val_out_caps_loss: 0.0037 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00067: val_loss did not improve from 0.01159
# Epoch 68/70
# 421/421 [==============================] - 254s 604ms/step - loss: 0.0095 - out_caps_loss: 0.0045 - decoder_loss: 0.0128 - out_caps_acc: 0.9951 - val_loss: 0.0118 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0208 - val_out_caps_acc: 0.9960
#
# Epoch 00068: val_loss did not improve from 0.01159
# Epoch 69/70
# 421/421 [==============================] - 251s 596ms/step - loss: 0.0095 - out_caps_loss: 0.0045 - decoder_loss: 0.0128 - out_caps_acc: 0.9955 - val_loss: 0.0118 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0209 - val_out_caps_acc: 0.9960
#
# Epoch 00069: val_loss did not improve from 0.01159
# Epoch 70/70
# 421/421 [==============================] - 256s 607ms/step - loss: 0.0091 - out_caps_loss: 0.0041 - decoder_loss: 0.0128 - out_caps_acc: 0.9959 - val_loss: 0.0118 - val_out_caps_loss: 0.0036 - val_decoder_loss: 0.0208 - val_out_caps_acc: 0.9960
#
# Epoch 00070: val_loss did not improve from 0.01159
# Trained model saved to 'trained_model.h5'

# %% [markdown]
# # Inference: Evaluate model performance

# %% [markdown]
# Load the best weights

# %% [markdown]
# Final Weights(trained model) for this training process

# %%
# model.load_weights('trained_model.h5')

# %%
# y_pred, x_recon = model.predict([x_test, y_test], batch_size=args.batch_size)
# print('Test acc:', np.sum(np.argmax(y_pred, 1) == np.argmax(y_test, 1)) / y_test.shape[0])
# Out:
# Test acc: 0.9847

# %%
# dig_pred, dig_recon = model.predict([x_dig[:10000], y_dig[:10000]], batch_size=args.batch_size)
# print('Dig acc:', np.sum(np.argmax(dig_pred, 1) == np.argmax(y_dig, 1)) / y_dig.shape[0])
# Out:
# Dig acc: 0.9066

# %% [markdown]
# The same model trained for 50 epochs does better on both the test sets, the model probably overfit on training for than 50 epochs

# %%
model.load_weights('best.h5')

# %%
y_pred, x_recon = model.predict([x_test, y_test], batch_size=args.batch_size)
print('Test acc:', np.sum(np.argmax(y_pred, 1) == np.argmax(y_test, 1)) / y_test.shape[0])
# Out:
# Test acc: 0.9852

# %%
dig_pred, dig_recon = model.predict([x_dig[:10000], y_dig[:10000]], batch_size=args.batch_size)
print('Dig acc:', np.sum(np.argmax(dig_pred, 1) == np.argmax(y_dig, 1)) / y_dig.shape[0])
# Out:
# Dig acc: 0.9109

# %% [markdown]
# # Visualisation

# %% [markdown]
# **Visualise the model architecture in use**

# %% [markdown]
# Encoder/Capsule network

# %%
from IPython.display import Image
Image('model.png', width=750, height=750)

# %% [markdown]
# Decoder/Reconstruction network

# %%
Image('decoder.png', width=450, height=750)

# %%
pd.set_option('display.max_columns', None)

df = pd.read_csv('log.csv')
print(df.columns)

# %% [markdown]
# **Filter the values to visualise**

# %%
# loss
loss = df['loss'].to_list()
val_loss = df['val_loss'].to_list()

# Break-down the losses into components
out_caps_loss = df['out_caps_loss'].to_list()
val_out_caps_loss = df['val_out_caps_loss'].to_list()

decoder_loss = df['decoder_loss'].to_list()
val_decoder_loss = df['val_decoder_loss'].to_list()

# accuracy
out_caps_acc = df['out_caps_acc'].to_list()
val_out_caps_acc = df['val_out_caps_acc'].to_list()

# %% [markdown]
# **Configure plotting tool(here: matplotlib)**

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 5, 10
plt.style.use('fivethirtyeight')
plt.rc('grid', color='k', linestyle='--')
plt.rc('xtick', direction='out', color='black')
plt.rc('ytick', direction='out', color='black')
plt.rc('axes', facecolor='#E6E6E6', edgecolor='gray', axisbelow=True, grid=True)

# %% [markdown]
# **Plot the loss and accuracy values**

# %%
epochs = range(len(loss))

params = {'left' : 1,
          'right' : 3,
          'bottom' : 1,
          'top' : 3, 
          'wspace' : 1,          
          'hspace' : 0.2}
              
plt.subplots_adjust(**params)

# Plot retrieved data : accuracy
plt.subplot(221)
plt.plot(epochs, out_caps_acc)
plt.plot(epochs, val_out_caps_acc)
plt.title("Training and Validation Accuracy")

# Plot retrieved data : loss
plt.subplot(222)
plt.plot(epochs, loss)
plt.plot(epochs, val_loss)
plt.title("Training and Validation Loss")

# Plot retrieved data : capsule loss
plt.subplot(223)
plt.plot(epochs, out_caps_loss)
plt.plot(epochs, val_out_caps_loss)
plt.title("Training and Validation Capsule Loss")

# Plot retrieved data : reconstruction loss
plt.subplot(224)
plt.plot(epochs, decoder_loss)
plt.plot(epochs, val_decoder_loss)
plt.title("Training and Validation Reconstruction Loss")
# Out:
# Text(0.5, 1.0, 'Training and Validation Reconstruction Loss')

# %% [markdown]
# **Reconstruction**

# %% [markdown]
# Pick out 1 random image from each of test and dig sets and compare their reconstructions with the original image

# %%
import random
index = random.randint(1, 10000)

print(f'For the sample number {index} in the test set')
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(12, 12))
ax1.set_title(f'Actual image at {index}, actual number is {np.argmax(y_test[index])}', fontsize=12, fontweight='bold')
ax1.imshow(x_test[index].reshape(28, 28), cmap=plt.cm.binary)
ax2.set_title(f'Reconstructed image at {index}, predicted number is {np.argmax(y_pred[index])}', fontsize=12, fontweight='bold')
ax2.imshow(x_recon[index].reshape(28, 28), cmap=plt.cm.binary)
# Out:
# For the sample number 163 in the test set

# %%
index = random.randint(1, 10000)

print(f'For the sample number {index} in the test set')
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(12, 12))
ax1.set_title(f'Actual DIG image at {index}, actual number is {np.argmax(y_dig[index])}', fontsize=12, fontweight='bold')
ax1.imshow(x_dig[index].reshape(28, 28), cmap=plt.cm.binary)
ax2.set_title(f'Reconstructed DIG image at {index}, predicted number is {np.argmax(dig_pred[index])}', fontsize=12, fontweight='bold')
ax2.imshow(dig_recon[index].reshape(28, 28), cmap=plt.cm.binary)
# Out:
# For the sample number 9702 in the test set

# %% [markdown]
# **Plot the confusion matrix**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

labels = []
preds = []
for i in range(y_test.shape[0]):
  labels.append(np.argmax(y_test[i]))
  preds.append(np.argmax(y_pred[i]))

plt.figure(figsize=(10, 10))
plt.title("Test Set Confusion Matrix", fontsize=18, fontweight="bold")
cm = confusion_matrix(labels, preds)
sn.set(font_scale=1.4) # for label size
sn.heatmap(cm, annot=True, fmt='g', cmap="gist_earth", annot_kws={"size": 12}) # flag_r, copper, gist_earth, icefire

plt.show()

dig_labels = []
dig_preds = []
for i in range(y_dig.shape[0]):
  dig_labels.append(np.argmax(y_dig[i]))
  dig_preds.append(np.argmax(dig_pred[i]))

plt.figure(figsize=(10, 10))
plt.title("DIG-10K Set Confusion Matrix", fontsize=18, fontweight="bold")
dig_cm = confusion_matrix(dig_labels, dig_preds)
sn.set(font_scale=1.4) # for label size
sn.heatmap(dig_cm, annot=True, fmt='g', cmap="gist_earth", annot_kws={"size": 12}) # flag_r, copper, gist_earth, icefire

plt.show()

# %% [markdown]
# # Digit manipulation

# %% [markdown]
# **Manipulate the each of the digit caps dimensions independently and visualise its effect on the input image.**

# %% [markdown]
# Utility function to stack rows of manipulated digit images

# %%
import math
def combine_images(generated_images, height=None, width=None):
    num = generated_images.shape[0]
    if width is None and height is None: # both height and width not given
        width = int(math.sqrt(num))
        height = int(math.ceil(float(num)/width))
    elif width is not None and height is None:  # height not given
        height = int(math.ceil(float(num)/width))
    elif height is not None and width is None:  # width not given
        width = int(math.ceil(float(num)/height))

    shape = generated_images.shape[1:3]
    image = np.zeros((height*shape[0], width*shape[1]),
                    dtype=generated_images.dtype)
    for index, img in enumerate(generated_images):
        i = int(index/width)
        j = index % width
        image[i*shape[0]:(i+1)*shape[0], j*shape[1]:(j+1)*shape[1]] = img[:, :, 0]
    return image

# %% [markdown]
# Utility function to manipulate digit caps output vector dimensions and visualise their effects on the reconstructed images

# %%
from PIL import Image
def manipulate_latent(model, data, digit):
    x_test, y_test = data
    result = np.argmax(y_test, 1) == digit # bool array
    index = np.random.randint(low=0, high=sum(result) - 1) # select
    x, y = x_test[result][index], y_test[result][index]
    x, y = np.expand_dims(x, 0), np.expand_dims(y, 0)
    noise = np.zeros([1, num_classes, args.digit_caps_dim_vector]) # init the noise matrix
    x_recons = []
    for dim in range(args.digit_caps_dim_vector):
      # there are digit_caps_dim_vector dimensions to be tweaked, each such dimension will see the 11 distortions given below
        for r in [-0.25, -0.2, -0.15, -0.1, -0.05, 0, 0.05, 0.1, 0.15, 0.2, 0.25]:
            tmp = np.copy(noise)
            tmp[:,:,dim] = r
            x_recon = model.predict([x, y, tmp])
            x_recons.append(x_recon)

    x_recons = np.concatenate(x_recons)
    img = combine_images(x_recons, height=args.digit_caps_dim_vector)
    image = img*255
    Image.fromarray(image.astype(np.uint8)).save('manipulate/manipulate-%d.png' %digit)
    print('Result saved to manipulate/manipulate-%d.png' % (digit))

# %% [markdown]
# Create the manipulate directory if it does not already exist

# %%
# !pwd
# Out:
# /content

# %%
# %%bash
# if [ -s "manipulate" ]; then
# echo "directory named manipulate exists at $(pwd manipulate)" || exit
# else
# mkdir -p manipulate && echo "created directory manipulate at $(pwd manipulate)" || exit
# fi
# Out:
# directory named manipulate exists at /content

# %%
for digit in range(10):
  manipulate_latent(manip_model, (x_test, y_test), digit)
# Out:
# Result saved to manipulate/manipulate-0.png
# Result saved to manipulate/manipulate-1.png
# Result saved to manipulate/manipulate-2.png
# Result saved to manipulate/manipulate-3.png
# Result saved to manipulate/manipulate-4.png
# Result saved to manipulate/manipulate-5.png
# Result saved to manipulate/manipulate-6.png
# Result saved to manipulate/manipulate-7.png
# Result saved to manipulate/manipulate-8.png
# Result saved to manipulate/manipulate-9.png

# %% [markdown]
# Download the results to local machine

# %%
# !zip -r /content/manipulated_images.zip /content/manipulate
# Out:
#   adding: content/manipulate/ (stored 0%)
#   adding: content/manipulate/manipulate-0.png (deflated 0%)
#   adding: content/manipulate/manipulate-1.png (deflated 0%)
#   adding: content/manipulate/manipulate-8.png (deflated 0%)
#   adding: content/manipulate/manipulate-5.png (deflated 0%)
#   adding: content/manipulate/manipulate-9.png (deflated 0%)
#   adding: content/manipulate/manipulate-6.png (deflated 0%)
#   adding: content/manipulate/manipulate-3.png (deflated 0%)
#   adding: content/manipulate/manipulate-2.png (deflated 0%)
#   adding: content/manipulate/manipulate-7.png (deflated 0%)
#   adding: content/manipulate/manipulate-4.png (deflated 0%)

# %%
from google.colab import files
files.download("/content/manipulated_images.zip")
